# %%
import geopandas as gpd

gdf = gpd.read_file("C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg")
print(gdf.head())
# Out:
# c:\Users\a_sri\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'malaysia-singapore-brunei.gpkg': 'gis_osm_traffic_free' (default), 'gis_osm_places_free', 'gis_osm_pois_free', 'gis_osm_pofw_free', 'gis_osm_transport_free', 'gis_osm_natural_free', 'gis_osm_roads_free', 'gis_osm_waterways_free', 'gis_osm_railways_free', 'gis_osm_places_a_free', 'gis_osm_pois_a_free', 'gis_osm_landuse_a_free', 'gis_osm_traffic_a_free', 'gis_osm_buildings_a_free', 'gis_osm_water_a_free', 'gis_osm_transport_a_free', 'gis_osm_pofw_a_free', 'gis_osm_natural_a_free'. Specify layer parameter to avoid this warning.
#   result = read_func(
#      osm_id  code             fclass name                   geometry
# 0  25451918  5206  motorway_junction       POINT (103.97394 1.32757)
# 1  25455287  5206  motorway_junction         POINT (103.874 1.29544)
# 2  25455292  5206  motorway_junction        POINT (103.9085 1.30101)
# ...

# %%
import fiona 

layers = fiona.listlayers("C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg")
print(layers)
print(len(layers))
# Out:
# ['gis_osm_traffic_free', 'gis_osm_places_free', 'gis_osm_pois_free', 'gis_osm_pofw_free', 'gis_osm_transport_free', 'gis_osm_natural_free', 'gis_osm_roads_free', 'gis_osm_waterways_free', 'gis_osm_railways_free', 'gis_osm_places_a_free', 'gis_osm_pois_a_free', 'gis_osm_landuse_a_free', 'gis_osm_traffic_a_free', 'gis_osm_buildings_a_free', 'gis_osm_water_a_free', 'gis_osm_transport_a_free', 'gis_osm_pofw_a_free', 'gis_osm_natural_a_free']
# 18

# %%
roads = gpd.read_file("C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg", layer="gis_osm_roads_free")
print(roads.head())

# %%
import geopandas as gpd

gdf = gpd.read_file(
    r"C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg",
    layer="gis_osm_pois_free"
)

# %%
print(gdf.columns)
# Out:
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')

# %%
gdf.head()
# Out:
#       osm_id  code       fclass                name                   geometry
# 0  149979816  2721   attraction        Textile Walk  POINT (101.80315 2.85427)
# 1  158731933  2501  supermarket          HeroMarket  POINT (101.54722 3.08735)
# 2  158732943  2504         mall             Ole Ole  POINT (101.51696 3.04347)
# 3  168931187  2301   restaurant          Seri Bunga   POINT (101.5386 3.05107)
# 4  168935492  2101     pharmacy  Farmasi Mesra Maju   POINT (101.5423 3.05531)

# %%
print(gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 102557 entries, 0 to 102556
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   osm_id    102557 non-null  str
#  1   code      102557 non-null  int32
#  2   fclass    102557 non-null  str
#  3   name      102557 non-null  str
#  4   geometry  102557 non-null  geometry
# dtypes: geometry(1), int32(1), str(3)
# memory usage: 3.5 MB
# None

# %%
import fiona
import geopandas as gpd

layers = fiona.listlayers(r"C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg")

for layer in layers:
    gdf = gpd.read_file(
        r"C:\Projects\HERE_Hackathon\HERE_Mark42\Data\malaysia-singapore-brunei.gpkg",
        layer=layer
    )
    print(f"\nLayer: {layer}")
    print(gdf.columns)
# Out:
# Layer: gis_osm_traffic_free
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_places_free
# Index(['osm_id', 'code', 'fclass', 'population', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_pois_free
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_pofw_free
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_transport_free
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_natural_free
# Index(['osm_id', 'code', 'fclass', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_roads_free
# Index(['osm_id', 'code', 'fclass', 'name', 'ref', 'oneway', 'maxspeed',
#        'layer', 'bridge', 'tunnel', 'geometry'],
#       dtype='str')
#
# Layer: gis_osm_waterways_free
# Index(['osm_id', 'code', 'fclass', 'width', 'name', 'geometry'], dtype='str')
#
# Layer: gis_osm_railways_free
# ...
